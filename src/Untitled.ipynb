# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report, accuracy_score

# load data
df = pd.read_csv("../dataset/spam.csv")

# label convert
df['label'] = df['label'].map({'not_spam': 0, 'spam': 1})

# clean text use karo
X = df['clean_text'].fillna("").astype(str)
y = df['label']

# split (sirf ek baar)
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42
)

# pipeline
pipeline = Pipeline([
    ('tfidf', TfidfVectorizer(max_features=5000)),
    ('knn', KNeighborsClassifier(n_neighbors=5))
])

# train
pipeline.fit(X_train, y_train)

# predict
y_pred = pipeline.predict(X_test)

# evaluate
print("Accuracy:", accuracy_score(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.9547492865878516
#               precision    recall  f1-score   support
#
#            0       1.00      0.91      0.95      1205
#            1       0.92      1.00      0.96      1248
#
#     accuracy                           0.95      2453
#    macro avg       0.96      0.95      0.95      2453
# weighted avg       0.96      0.95      0.95      2453

# %%
import pickle
import os

os.makedirs("../model", exist_ok=True)
pickle.dump(pipeline, open("../model/model_knn.pkl", "wb"))
