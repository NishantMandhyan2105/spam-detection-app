# %%
import pandas as pd

# %%
df = pd.read_csv("spam.csv")

# %%
print(df.head())
# Out:
#                                                 text     label
# 0  hey I am looking for Xray baggage datasets can...  not_spam
# 1  "Get rich quick! Make millions in just days wi...      spam
# 2  URGENT MESSAGE: YOU WON'T BELIEVE WHAT WE HAVE...      spam
# 3  [Google AI Blog: Contributing Data to Deepfake...  not_spam
# 4  Trying to see if anyone already has timestamps...  not_spam

# %%
print(df.isnull().sum())
# Out:
# text     0
# label    0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
import re

# %%
def clean_text(text):
    text = text.lower()
    text = re.sub(r'[^a-zA-Z]', ' ', text)
    text = re.sub(r'\s+', ' ', text)
    return text.strip()

# %%
df['clean_text'] = df['text'].apply(clean_text)

# %%
print(df[['text', 'clean_text']].head())
# Out:
#                                                 text  \
# 0  hey I am looking for Xray baggage datasets can...
# 1  "Get rich quick! Make millions in just days wi...
# 2  URGENT MESSAGE: YOU WON'T BELIEVE WHAT WE HAVE...
# 3  [Google AI Blog: Contributing Data to Deepfake...
# 4  Trying to see if anyone already has timestamps...
#
#                                           clean_text
# 0  hey i am looking for xray baggage datasets can...
# 1  get rich quick make millions in just days with...
# 2  urgent message you won t believe what we have ...
# 3  google ai blog contributing data to deepfake d...
# 4  trying to see if anyone already has timestamps...

# %%
from sklearn.feature_extraction.text import ENGLISH_STOP_WORDS

# %%
def remove_stopwords(text):
    return " ".join([word for word in text.split() if word not in ENGLISH_STOP_WORDS])

# %%
print(list(ENGLISH_STOP_WORDS)[:20])
# Out:
# ['not', 'amoungst', 'therefore', 'thin', 'full', 'though', 'each', 'its', 'herein', 'several', 'take', 'never', 'front', 'along', 'fill', 'via', 'mine', 'thereby', 'a', 'everyone']

# %%
df['clean_text'] = df['clean_text'].apply(remove_stopwords)

# %%
df.to_csv("spam.csv", index=False)

# %%
df.head()
# Out:
#                                                 text     label  \
# 0  hey I am looking for Xray baggage datasets can...  not_spam
# 1  "Get rich quick! Make millions in just days wi...      spam
# 2  URGENT MESSAGE: YOU WON'T BELIEVE WHAT WE HAVE...      spam
# 3  [Google AI Blog: Contributing Data to Deepfake...  not_spam
# 4  Trying to see if anyone already has timestamps...  not_spam
#
#                                           clean_text
# 0          hey looking xray baggage datasets provide
# 1  rich quick make millions just days new revolut...
# 2  urgent message won t believe offer hey yeah ey...
# 3  google ai blog contributing data deepfake dete...
# 4  trying timestamps key events happened presiden...
